# %%
from tsim import Circuit

# %%
c = Circuit.from_file("../circuits/msd_5.stim")

# %%
c.diagram(height=600)

# %%
c.diagram("pyzx", scale_horizontally=1.5);

# %%
c.diagram("pyzx-dets")

# %%
sampler = c.compile_detector_sampler()

# %%
sampler.sample(shots=100)
